# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
df=pd.read_excel("Ex2.xlsx", sheet_name="Sheet5")
df.head()
# Out:
#    Index     Name   Gender                                Designation  Age  \
# 0      1    Liam      Male                                   Producer   37
# 1      2  Olivia    Female  Cinematographer (Director of Photography)   48
# 2      3    Noah      Male                                   Director   24
# 3      4    Emma    Female                                     Editor   56
# 4      5     Ava    Female                               Art Director   42
#
#    Experience  Cost involved in recruiting  Induction program cost  \
# 0           1                          400                     800
# 1          13                          500                    1200
# 2           8                          450                     900
# 3          10                          600                    1100
# 4          14                          250                     600
#
#    New hires performance satisfaction  Time to fill  ...  \
# ...

# %%
df1=df[["Age","Experience","Target Given","Target Achieved","Performance Differential","Performance rating","Content Satisfaction","Sourcing Channel","Hours of trg"]]
df1.head()
# Out:
#    Age  Experience  Target Given  Target Achieved  Performance Differential  \
# 0   37           1            55               30                        25
# 1   48          13            60               45                        15
# 2   24           8            45               30                        15
# 3   56          10            60               30                        30
# 4   42          14            60               55                         5
#
#    Performance rating  Content Satisfaction  Sourcing Channel  Hours of trg
# 0                   3                     2                 1            25
# 1                   3                     3                 2            13
# 2                   3                     3                 3             8
# 3                   1                     3                 4             9
# 4                   3                     3                 5            15

# %%
correlation=df1.corr()
plt.figure(figsize=(24,24))
sns.heatmap(correlation,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Experience','Performance rating']])

scaled_df = pd.DataFrame(scaled, columns=['Experience','Performance rating'])
k_opt=3
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Experience'], scaled_df['Performance rating'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Performance rating','Hours of trg']])

scaled_df = pd.DataFrame(scaled, columns=['Performance rating','Hours of trg'])
scaled_df.head()
k_opt=4
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Performance rating'], scaled_df['Hours of trg'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Performance rating','Sourcing Channel']])

scaled_df = pd.DataFrame(scaled, columns=['Performance rating','Sourcing Channel'])
scaled_df.head()
k_opt=3
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Performance rating'], scaled_df['Sourcing Channel'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Performance rating','Content Satisfaction']])

scaled_df = pd.DataFrame(scaled, columns=['Performance rating','Content Satisfaction'])
scaled_df.head()
k_opt=3
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Performance rating'], scaled_df['Content Satisfaction'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
linkage_matrix = linkage(correlation, method='ward')

# Plot the dendrogram
plt.figure(figsize=(8, 6))
dendrogram(linkage_matrix, labels=correlation.index, orientation='top')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.xticks(rotation=90)
plt.ylabel('Distance')
plt.show()
