# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
df=pd.read_excel("Ex2.xlsx", sheet_name="Sheet5")
df.head()
# Out:
#    Index     Name   Gender                                Designation  Age  \
# 0      1    Liam      Male                                   Producer   37
# 1      2  Olivia    Female  Cinematographer (Director of Photography)   48
# 2      3    Noah      Male                                   Director   24
# 3      4    Emma    Female                                     Editor   56
# 4      5     Ava    Female                               Art Director   42
#
#    Experience  Cost involved in recruiting  Induction program cost  \
# 0           1                          400                     800
# 1          13                          500                    1200
# 2           8                          450                     900
# 3          10                          600                    1100
# 4          14                          250                     600
#
#    New hires performance satisfaction  Time to fill  ...  \
# ...

# %%
df1=df[["Age","Experience","Type of Training","Hours of trg","Content Satisfaction","Skill development","Knowledge level"]]
df1.head()
# Out:
#    Age  Experience  Type of Training  Hours of trg  Content Satisfaction  \
# 0   37           1                 2            25                     2
# 1   48          13                 2            13                     3
# 2   24           8                 1             8                     3
# 3   56          10                 1             9                     3
# 4   42          14                 1            15                     3
#
#    Skill development  Knowledge level
# 0                  1                1
# 1                  3                1
# 2                  2                2
# 3                  1                1
# 4                  1                1

# %%
correlation=df1.corr()
plt.figure(figsize=(7,7))
sns.heatmap(correlation,annot=True,cmap='viridis')
correlation.head()
# Out:
#                            Age  Experience  Type of Training  Hours of trg  \
# Age                   1.000000    0.040869          0.016075     -0.188682
# Experience            0.040869    1.000000         -0.012931     -0.032642
# Type of Training      0.016075   -0.012931          1.000000     -0.014944
# Hours of trg         -0.188682   -0.032642         -0.014944      1.000000
# Content Satisfaction  0.079389    0.083034          0.044704     -0.066572
#
#                       Content Satisfaction  Skill development  Knowledge level
# Age                               0.079389           0.006061        -0.018743
# Experience                        0.083034          -0.042070         0.022947
# Type of Training                  0.044704           0.028537        -0.061465
# Hours of trg                     -0.066572          -0.077295        -0.017529
# Content Satisfaction              1.000000           0.026203         0.118783

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Type of Training','Content Satisfaction']])

scaled_df = pd.DataFrame(scaled, columns=['Type of Training','Content Satisfaction'])
scaled_df.head()
k_opt=3
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Type of Training'], scaled_df['Content Satisfaction'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
scaler = StandardScaler()
scaled= scaler.fit_transform(df[['Skill development','Hours of trg']])

scaled_df = pd.DataFrame(scaled, columns=['Skill development','Hours of trg'])
scaled_df.head()
k_opt=3
model = KMeans(n_clusters=k_opt,random_state =42,n_init=20)
model.fit(scaled_df)

scaled_df['labels'] = model.labels_
cluster_centers = model.cluster_centers_

plt.figure(figsize=(8, 6))
plt.scatter(scaled_df['Skill development'], scaled_df['Hours of trg'] , c=scaled_df['labels'], cmap='viridis')
plt.title('K-means Clustering')
plt.xlabel('Job Satisfaction')
plt.ylabel('Relationship Between colleagues')
# Out:
# Text(0, 0.5, 'Relationship Between colleagues')

# %%
linkage_matrix = linkage(correlation, method='ward')

# Plot the dendrogram
plt.figure(figsize=(8, 6))
dendrogram(linkage_matrix, labels=correlation.index, orientation='top')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data Points')
plt.xticks(rotation=90)
plt.ylabel('Distance')
plt.show()
